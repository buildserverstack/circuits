# %% [markdown]
# # 03 — Vision Model Walkthrough
#
# Run this notebook to compute Grad-CAM, Gradient×Input, and per-channel activation scores for lightweight vision encoders (`resnet18`, `mobilenet_v3_small`, `vit_tiny_patch16_224`).

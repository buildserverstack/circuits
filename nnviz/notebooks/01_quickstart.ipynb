# %% [markdown]
# # 01 — Quickstart
#
# This notebook demonstrates how to configure the `nnviz` toolkit, capture activations for a text and vision model, and render the key visualizations described in the project specification.

# %% [markdown]
# # 02 — Text Model Walkthrough
#
# Use this notebook to examine transformer attention heads, token-level attributions, and activation sparsity for supported text backbones (e.g., `distilbert-base-uncased`, `gpt2`).
